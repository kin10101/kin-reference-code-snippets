# %%
# !uv add ollama --active
# Out:
# Using CPython 3.14.3 interpreter at: C:\Users\extpedj\AppData\Local\Python\pythoncore-3.14-64\python.exe
# Removed virtual environment at: c:\Users\extpedj\Desktop\kin-reference-code-snippets\.venv
# Creating virtual environment at: c:\Users\extpedj\Desktop\kin-reference-code-snippets\.venv
# Resolved 19 packages in 4ms
# Installed 18 packages in 393ms
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + certifi==2026.2.25
#  + click==8.3.1
#  + colorama==0.4.6
#  + fastapi==0.135.2
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.11
#  + ollama==0.6.1
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + starlette==1.0.0
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + uvicorn==0.42.0

# %%
import ollama

response = ollama.chat(model='llama3', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import ollama
#       3 response = ollama.chat(model='llama3', messages=[
#       4   {
#       5     'role': 'user',
#       6     'content': 'Why is the sky blue?',
#       7   },
#       8 ])
#       9 print(response['message']['content'])
#
# File c:\Users\extpedj\Desktop\kin-reference-code-snippets\.venv\Lib\site-packages\ollama\__init__.py:1
# ----> 1 from ollama._client import AsyncClient, Client
#       2 from ollama._types import (
#       3   ChatResponse,
#       4   EmbeddingsResponse,
#    (...)     19   WebSearchResponse,
#      20 )
#      22 __all__ = [
#      23   'AsyncClient',
#      24   'ChatResponse',
#    (...)     41   'WebSearchResponse',
#      42 ]
#
# File c:\Users\extpedj\Desktop\kin-reference-code-snippets\.venv\Lib\site-packages\ollama\_client.py:26
# ...
